# %% [markdown]
# # Full ETL of Data to MongoDB Instance

# %%
import os
import etl

import pymongo as mongo
import pandas as pd

# %% [markdown]
# ## Set File Paths

# %%
DATADIR = '/Users/admin/notebooks/fdic_data/financial_data_raw/'
FDIC_CODES = [3510, 3511, 7213, 628, 32188]

# %%
data_files = os.listdir(DATADIR)

# %%
mdrm_file = DATADIR + 'mdrm_codes'

# %% [markdown]
# ## Create DB Connections

# %%
client = mongo.MongoClient()
db = client['ffeic_bank']

# %%
fdic_collection = db['ffeic_reports']
company_collection = db['ffeic_company_info']
mdrm_collection = db['mdrm_info']

# %% [markdown]
# ## ETL Jobs

# %%
dicts = list()

for item in data_files:
    if item not in ('.ipynb_checkpoints', 'mdrm_codes'):
        filepath = os.path.join(DATADIR, item)
        print(filepath)
        fdic_etl = etl.FDICDataETL(filepath, FDIC_CODES)
        fdic_etl.full_etl(fdic_collection)
        company_etl = etl.FDICCompanyInfoETL(filepath, FDIC_CODES)
        company_etl.full_etl(company_collection)
# Out:
# /Users/admin/notebooks/fdic_data/financial_data_raw/FFIEC CDR Call Subset of Schedules 2013(1 of 3).txt
# /Users/admin/notebooks/fdic_data/financial_data_raw/FFIEC CDR Call Subset of Schedules 2013(2 of 3).txt
# /Users/admin/miniconda3/envs/working/lib/python3.6/site-packages/ipykernel_launcher.py:8: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#
# /Users/admin/miniconda3/envs/working/lib/python3.6/site-packages/ipykernel_launcher.py:10: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   # Remove the CWD from sys.path while we load stuff.
# /Users/admin/notebooks/fdic_data/financial_data_raw/FFIEC CDR Call Subset of Schedules 2013(3 of 3).txt
# /Users/admin/notebooks/fdic_data/financial_data_raw/FFIEC CDR Call Subset of Schedules 2014(1 of 3).txt
# /Users/admin/notebooks/fdic_data/financial_data_raw/FFIEC CDR Call Subset of Schedules 2014(2 of 3).txt
# /Users/admin/notebooks/fdic_data/financial_data_raw/FFIEC CDR Call Subset of Schedules 2014(3 of 3).txt
# /Users/admin/notebooks/fdic_data/financial_data_raw/FFIEC CDR Call Subset of Schedules 2015(1 of 3).txt
# /Users/admin/notebooks/fdic_data/financial_data_raw/FFIEC CDR Call Subset of Schedules 2015(2 of 3).txt
# /Users/admin/notebooks/fdic_data/financial_data_raw/FFIEC CDR Call Subset of Schedules 2015(3 of 3).txt
# /Users/admin/notebooks/fdic_data/financial_data_raw/FFIEC CDR Call Subset of Schedules 2016(1 of 3).txt
# /Users/admin/notebooks/fdic_data/financial_data_raw/FFIEC CDR Call Subset of Schedules 2016(2 of 3).txt
# /Users/admin/notebooks/fdic_data/financial_data_raw/FFIEC CDR Call Subset of Schedules 2016(3 of 3).txt
# /Users/admin/notebooks/fdic_data/financial_data_raw/FFIEC CDR Call Subset of Schedules 2017(1 of 2).txt
# /Users/admin/notebooks/fdic_data/financial_data_raw/FFIEC CDR Call Subset of Schedules 2017(2 of 2).txt

# %%
mdrm_etl = etl.MDRMInfoETL(mdrm_file)
mdrm_etl.full_etl(mdrm_collection)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-32-c44f6d2d0c92> in <module>()
#       1 mdrm_etl = etl.MDRMInfoETL(mdrm_file)
# ----> 2 mdrm_etl.full_etl(mdrm_collection)
#
# ~/notebooks/fdic_data/prototyping/etl.py in full_etl(self, mongo_collection)
#      67         """run a full etl job against a mongo_collection"""
#      68         transformed = self.transform()
# ---> 69         self.load(mongo_collection, transformed)
#      70
#      71
#
# ~/notebooks/fdic_data/prototyping/etl.py in load(self, mongo_collection, data)
#      61
#      62     def load(self, mongo_collection, data):
# ---> 63         assert mongo_collection.count() == 0
#      64         mongo_collection.insert_many(data)
#      65
#
# AssertionError:

# %% [markdown]
# ## Review

# %% [markdown]
# #### Collection Counts and Example Observations

# %%
mdrm_collection.count()
# Out:
# 777

# %%
for obs in mdrm_collection.find():
    print(obs)
# Out:
# {'_id': ObjectId('5946004ddbc5544250fb7f15'), 'mdrm_item': 'RIAD0093', 'description': 'SAVINGS DEPOSITS (INCLUDING MMDAS)', 'details': {'start_date': '2001-03-31', 'end_date': '9999-12-31', 'description': 'SAVINGS DEPOSITS (INCLUDING MMDAS)', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f16'), 'mdrm_item': 'RIAD0497', 'description': 'MARKETING AND OTHER PROFESSIONAL SERVICES', 'details': {'start_date': '2001-03-31', 'end_date': '9999-12-31', 'description': 'MARKETING AND OTHER PROFESSIONAL SERVICES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f17'), 'mdrm_item': 'RIAD1244', 'description': 'TAXABLE EQUIVALENT ADJUSTMENT TO "INCOME (LOSS) BEFORE INCOME TAXES AND EXTRAORDINARY ITEMS AND OTHER ADJUSTMENTS"', 'details': {'start_date': '1987-03-31', 'end_date': '1995-12-31', 'description': 'TAXABLE EQUIVALENT ADJUSTMENT TO "INCOME (LOSS) BEFORE INCOME TAXES AND EXTRAORDINARY ITEMS AND OTHER ADJUSTMENTS"', 'confidential': 'No', 'reporting_forms': 'FFIEC 031'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f18'), 'mdrm_item': 'RIAD2419', 'description': 'RECOVERIES ON ALLOWANCE FOR CREDIT LOSSES', 'details': {'start_date': '1998-03-31', 'end_date': '2000-12-31', 'description': 'RECOVERIES ON ALLOWANCE FOR CREDIT LOSSES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f19'), 'mdrm_item': 'RIAD2432', 'description': 'TITLE: LESS: CHARGE-OFFS IN ALLOWANCES FOR CREDIT LOSSES', 'details': {'start_date': '1998-03-31', 'end_date': '2000-12-31', 'description': 'TITLE: LESS: CHARGE-OFFS IN ALLOWANCES FOR CREDIT LOSSES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f1a'), 'mdrm_item': 'RIAD3120', 'description': 'RESERVE FOR BAD DEBT LOSSES ON LOANS', 'details': {'start_date': '1969-12-31', 'end_date': '1975-12-31', 'description': 'RESERVE FOR BAD DEBT LOSSES ON LOANS', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f1b'), 'mdrm_item': 'RIAD3121', 'description': 'ALLOWANCE FOR POSSIBLE LOAN LOSSES ON REAL ESTATE LOANS', 'details': {'start_date': '1979-03-31', 'end_date': '1985-12-31', 'description': 'ALLOWANCE FOR POSSIBLE LOAN LOSSES ON REAL ESTATE LOANS', 'confidential': 'No', 'reporting_forms': 'FDIC 8040/51'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f1c'), 'mdrm_item': 'RIAD3122', 'description': 'ALLOWANCE FOR POSSIBLE LOAN LOSSES ON OTHER LOANS', 'details': {'start_date': '1979-03-31', 'end_date': '1985-12-31', 'description': 'ALLOWANCE FOR POSSIBLE LOAN LOSSES ON OTHER LOANS', 'confidential': 'No', 'reporting_forms': 'FDIC 8040/51'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f1d'), 'mdrm_item': 'RIAD3123', 'description': 'ALLOWANCE FOR LOAN AND LEASE LOSSES', 'details': {'start_date': '1976-03-31', 'end_date': '1997-12-31', 'description': 'ALLOWANCE FOR LOAN AND LEASE LOSSES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f1e'), 'mdrm_item': 'RIAD3123', 'description': 'ALLOWANCE FOR LOAN AND LEASE LOSSES', 'details': {'start_date': '2001-03-31', 'end_date': '9999-12-31', 'description': 'ALLOWANCE FOR LOAN AND LEASE LOSSES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f1f'), 'mdrm_item': 'RIAD3124', 'description': 'ALLOWANCE FOR LOAN AND LEASE LOSSES - BALANCE END OF PREVIOUS CALENDAR YEAR', 'details': {'start_date': '1976-03-31', 'end_date': '9999-12-31', 'description': 'ALLOWANCE FOR LOAN AND LEASE LOSSES - BALANCE END OF PREVIOUS CALENDAR YEAR', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f20'), 'mdrm_item': 'RIAD3125', 'description': 'RESERVE FOR BAD DEBT LOSSES ON LOANS - PRECEDING YEAR', 'details': {'start_date': '1969-12-31', 'end_date': '1975-12-31', 'description': 'RESERVE FOR BAD DEBT LOSSES ON LOANS - PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f21'), 'mdrm_item': 'RIAD3126', 'description': 'ALLOWANCE FOR POSSIBLE LOAN LOSSES ON REAL ESTATE LOANS - BEGINNING BALANCE', 'details': {'start_date': '1979-06-30', 'end_date': '1985-12-31', 'description': 'ALLOWANCE FOR POSSIBLE LOAN LOSSES ON REAL ESTATE LOANS - BEGINNING BALANCE', 'confidential': 'No', 'reporting_forms': 'FDIC 8040/51'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f22'), 'mdrm_item': 'RIAD3127', 'description': 'ALLOWANCE FOR POSSIBLE LOAN LOSSES ON OTHER LOANS - BEGINNING BALANCE', 'details': {'start_date': '1979-06-30', 'end_date': '1985-12-31', 'description': 'ALLOWANCE FOR POSSIBLE LOAN LOSSES ON OTHER LOANS - BEGINNING BALANCE', 'confidential': 'No', 'reporting_forms': 'FDIC 8040/51'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f23'), 'mdrm_item': 'RIAD3128', 'description': 'ALLOCATED TRANSFER RISK RESERVES', 'details': {'start_date': '1984-03-31', 'end_date': '9999-12-31', 'description': 'ALLOCATED TRANSFER RISK RESERVES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f24'), 'mdrm_item': 'RIAD3130', 'description': 'OTHER RESERVES ON LOANS', 'details': {'start_date': '1969-12-31', 'end_date': '1975-12-31', 'description': 'OTHER RESERVES ON LOANS', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f25'), 'mdrm_item': 'RIAD3131', 'description': 'ALLOCATED TRANSFER RISK RESERVES - BEGINNING BALANCE', 'details': {'start_date': '1984-03-31', 'end_date': '9999-12-31', 'description': 'ALLOCATED TRANSFER RISK RESERVES - BEGINNING BALANCE', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f26'), 'mdrm_item': 'RIAD3132', 'description': 'RECOVERIES ON ALLOCATED TRANSFER RISK RESERVES', 'details': {'start_date': '1984-03-31', 'end_date': '9999-12-31', 'description': 'RECOVERIES ON ALLOCATED TRANSFER RISK RESERVES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f27'), 'mdrm_item': 'RIAD3133', 'description': 'CHARGE-OFFS ON ALLOCATED TRANSFER RISK RESERVES', 'details': {'start_date': '1984-03-31', 'end_date': '9999-12-31', 'description': 'CHARGE-OFFS ON ALLOCATED TRANSFER RISK RESERVES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f28'), 'mdrm_item': 'RIAD3134', 'description': 'ADJUSTMENTS TO ALLOCATED TRANSFER RISK RESERVES', 'details': {'start_date': '1984-03-31', 'end_date': '9999-12-31', 'description': 'ADJUSTMENTS TO ALLOCATED TRANSFER RISK RESERVES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f29'), 'mdrm_item': 'RIAD3135', 'description': 'OTHER RESERVES ON LOANS - PRECEDING YEAR', 'details': {'start_date': '1969-12-31', 'end_date': '1975-12-31', 'description': 'OTHER RESERVES ON LOANS - PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f2a'), 'mdrm_item': 'RIAD3140', 'description': 'RESERVES ON SECURITIES', 'details': {'start_date': '1969-12-31', 'end_date': '1975-12-31', 'description': 'RESERVES ON SECURITIES', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f2b'), 'mdrm_item': 'RIAD3145', 'description': 'RESERVES ON SECURITIES - PRECEDING YEAR', 'details': {'start_date': '1969-12-31', 'end_date': '1975-12-31', 'description': 'RESERVES ON SECURITIES - PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f2c'), 'mdrm_item': 'RIAD3196', 'description': 'REALIZED GAINS (LOSSES) ON AVAILABLE-FOR-SALE SECURITIES', 'details': {'start_date': '1994-03-31', 'end_date': '9999-12-31', 'description': 'REALIZED GAINS (LOSSES) ON AVAILABLE-FOR-SALE SECURITIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f2d'), 'mdrm_item': 'RIAD3200', 'description': 'SUBORDINATED NOTES AND DEBENTURES', 'details': {'start_date': '1969-12-31', 'end_date': '1975-12-31', 'description': 'SUBORDINATED NOTES AND DEBENTURES', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f2e'), 'mdrm_item': 'RIAD3202', 'description': 'CAPITAL NOTES AND DEBENTURES - PRECEDING YEAR', 'details': {'start_date': '1969-12-31', 'end_date': '1975-12-31', 'description': 'CAPITAL NOTES AND DEBENTURES - PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f2f'), 'mdrm_item': 'RIAD3210', 'description': 'TOTAL EQUITY CAPITAL', 'details': {'start_date': '1976-03-31', 'end_date': '9999-12-31', 'description': 'TOTAL EQUITY CAPITAL', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f30'), 'mdrm_item': 'RIAD3215', 'description': 'EQUITY CAPITAL, END OF PREVIOUS CALENDAR YEAR', 'details': {'start_date': '1976-03-31', 'end_date': '9999-12-31', 'description': 'EQUITY CAPITAL, END OF PREVIOUS CALENDAR YEAR', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f31'), 'mdrm_item': 'RIAD3216', 'description': 'EQUITY CAPITAL, ADJUSTMENTS FROM AMENDED REPORTS OF INCOME, NET', 'details': {'start_date': '1978-12-31', 'end_date': '2000-12-31', 'description': 'EQUITY CAPITAL, ADJUSTMENTS FROM AMENDED REPORTS OF INCOME, NET', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f32'), 'mdrm_item': 'RIAD3217', 'description': 'EQUITY CAPITAL, MOST RECENTLY REPORTED FOR THE END OF PREVIOUS CALENDAR YEAR (I.E., AFTER ADJUSTMENTS FROM AMENDED REPORTS OF INCOME)', 'details': {'start_date': '1978-12-31', 'end_date': '9999-12-31', 'description': 'EQUITY CAPITAL, MOST RECENTLY REPORTED FOR THE END OF PREVIOUS CALENDAR YEAR (I.E., AFTER ADJUSTMENTS FROM AMENDED REPORTS OF INCOME)', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f33'), 'mdrm_item': 'RIAD3218', 'description': 'ADJUSTMENTS - EQUITY CAPITAL', 'details': {'start_date': '1978-12-31', 'end_date': '9999-12-31', 'description': 'ADJUSTMENTS - EQUITY CAPITAL', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f34'), 'mdrm_item': 'RIAD3220', 'description': 'PREFERRED STOCK, TOTAL', 'details': {'start_date': '1969-12-31', 'end_date': '1982-12-31', 'description': 'PREFERRED STOCK, TOTAL', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f35'), 'mdrm_item': 'RIAD3225', 'description': 'PREFERRED STOCK - PRECEDING YEAR', 'details': {'start_date': '1969-12-31', 'end_date': '1982-12-31', 'description': 'PREFERRED STOCK - PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f36'), 'mdrm_item': 'RIAD3226', 'description': 'PREFERRED STOCK - ADJUSTMENTS', 'details': {'start_date': '1978-12-31', 'end_date': '1982-12-31', 'description': 'PREFERRED STOCK - ADJUSTMENTS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f37'), 'mdrm_item': 'RIAD3227', 'description': 'PREFERRED STOCK - ADJUSTED PRECEDING YEAR', 'details': {'start_date': '1978-12-31', 'end_date': '1982-12-31', 'description': 'PREFERRED STOCK - ADJUSTED PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f38'), 'mdrm_item': 'RIAD3230', 'description': 'COMMON STOCK', 'details': {'start_date': '1969-12-31', 'end_date': '1982-12-31', 'description': 'COMMON STOCK', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f39'), 'mdrm_item': 'RIAD3235', 'description': 'COMMON STOCK - PRECEDING YEAR', 'details': {'start_date': '1969-12-31', 'end_date': '1982-12-31', 'description': 'COMMON STOCK - PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f3a'), 'mdrm_item': 'RIAD3236', 'description': 'COMMON STOCK - ADJUSTMENTS', 'details': {'start_date': '1978-12-31', 'end_date': '1982-12-31', 'description': 'COMMON STOCK - ADJUSTMENTS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f3b'), 'mdrm_item': 'RIAD3237', 'description': 'COMMON STOCK - ADJUSTED PRECEDING YEAR', 'details': {'start_date': '1978-12-31', 'end_date': '1982-12-31', 'description': 'COMMON STOCK - ADJUSTED PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f3c'), 'mdrm_item': 'RIAD3240', 'description': 'SURPLUS', 'details': {'start_date': '1969-12-31', 'end_date': '1982-12-31', 'description': 'SURPLUS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f3d'), 'mdrm_item': 'RIAD3245', 'description': 'SURPLUS - PRECEDING YEAR', 'details': {'start_date': '1969-12-31', 'end_date': '1982-12-31', 'description': 'SURPLUS - PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f3e'), 'mdrm_item': 'RIAD3246', 'description': 'SURPLUS - ADJUSTMENTS', 'details': {'start_date': '1978-12-31', 'end_date': '1982-12-31', 'description': 'SURPLUS - ADJUSTMENTS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f3f'), 'mdrm_item': 'RIAD3247', 'description': 'UNDIVIDED PROFITS AND CAPITAL RESERVES (RETAINED EARNINGS)', 'details': {'start_date': '1976-03-31', 'end_date': '1982-12-31', 'description': 'UNDIVIDED PROFITS AND CAPITAL RESERVES (RETAINED EARNINGS)', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f40'), 'mdrm_item': 'RIAD3248', 'description': 'UNDIVIDED PROFITS AND CAPITAL RESERVES - PRECEDING YEAR', 'details': {'start_date': '1976-03-31', 'end_date': '1982-12-31', 'description': 'UNDIVIDED PROFITS AND CAPITAL RESERVES - PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f41'), 'mdrm_item': 'RIAD3249', 'description': 'SURPLUS - ADJUSTED PRECEDING YEAR', 'details': {'start_date': '1978-12-31', 'end_date': '1982-12-31', 'description': 'SURPLUS - ADJUSTED PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f42'), 'mdrm_item': 'RIAD3250', 'description': 'RETAINED EARNINGS: ENDING BALANCE', 'details': {'start_date': '1969-12-31', 'end_date': '1975-12-31', 'description': 'RETAINED EARNINGS: ENDING BALANCE', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f43'), 'mdrm_item': 'RIAD3250', 'description': 'RETAINED EARNINGS: ENDING BALANCE', 'details': {'start_date': '1979-03-31', 'end_date': '1985-12-31', 'description': 'RETAINED EARNINGS: ENDING BALANCE', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f44'), 'mdrm_item': 'RIAD3251', 'description': 'UNDIVIDED PROFITS AND CAPITAL RESERVES - ADJUSTMENTS', 'details': {'start_date': '1978-12-31', 'end_date': '1982-12-31', 'description': 'UNDIVIDED PROFITS AND CAPITAL RESERVES - ADJUSTMENTS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f45'), 'mdrm_item': 'RIAD3252', 'description': 'UNDIVIDED PROFITS AND CAPITAL RESERVES - ADJUSTED PRECEDING YEAR', 'details': {'start_date': '1978-12-31', 'end_date': '1982-12-31', 'description': 'UNDIVIDED PROFITS AND CAPITAL RESERVES - ADJUSTED PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f46'), 'mdrm_item': 'RIAD3255', 'description': 'UNDIVIDED PROFITS - PRECEDING YEAR', 'details': {'start_date': '1969-12-31', 'end_date': '1975-12-31', 'description': 'UNDIVIDED PROFITS - PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f47'), 'mdrm_item': 'RIAD3255', 'description': 'UNDIVIDED PROFITS - PRECEDING YEAR', 'details': {'start_date': '1979-03-31', 'end_date': '1985-12-31', 'description': 'UNDIVIDED PROFITS - PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f48'), 'mdrm_item': 'RIAD3256', 'description': 'PERPETUAL PREFERRED STOCK, COMMON STOCK, AND SURPLUS - PRECEDING YEAR', 'details': {'start_date': '1984-06-30', 'end_date': '1985-12-31', 'description': 'PERPETUAL PREFERRED STOCK, COMMON STOCK, AND SURPLUS - PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'FDIC 8040/51'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f49'), 'mdrm_item': 'RIAD3257', 'description': 'PERPETUAL PREFERRED STOCK, COMMON STOCK, AND SURPLUS', 'details': {'start_date': '1984-06-30', 'end_date': '1985-12-31', 'description': 'PERPETUAL PREFERRED STOCK, COMMON STOCK, AND SURPLUS', 'confidential': 'No', 'reporting_forms': 'FDIC 8040/51'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f4a'), 'mdrm_item': 'RIAD3260', 'description': 'RESERVES FOR CONTINGENCIES AND OTHER CAPITAL RESERVES', 'details': {'start_date': '1969-12-31', 'end_date': '1975-12-31', 'description': 'RESERVES FOR CONTINGENCIES AND OTHER CAPITAL RESERVES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f4b'), 'mdrm_item': 'RIAD3260', 'description': 'RESERVES FOR CONTINGENCIES AND OTHER CAPITAL RESERVES', 'details': {'start_date': '1979-03-31', 'end_date': '1985-12-31', 'description': 'RESERVES FOR CONTINGENCIES AND OTHER CAPITAL RESERVES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f4c'), 'mdrm_item': 'RIAD3265', 'description': 'RESERVES FOR CONTINGENCIES AND OTHER CAPITAL ACCOUNTS - PRECEDING YEAR', 'details': {'start_date': '1969-12-31', 'end_date': '1975-12-31', 'description': 'RESERVES FOR CONTINGENCIES AND OTHER CAPITAL ACCOUNTS - PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f4d'), 'mdrm_item': 'RIAD3265', 'description': 'RESERVES FOR CONTINGENCIES AND OTHER CAPITAL ACCOUNTS - PRECEDING YEAR', 'details': {'start_date': '1979-03-31', 'end_date': '1985-12-31', 'description': 'RESERVES FOR CONTINGENCIES AND OTHER CAPITAL ACCOUNTS - PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f4e'), 'mdrm_item': 'RIAD3270', 'description': 'TOTAL CAPITAL ACCOUNTS', 'details': {'start_date': '1969-12-31', 'end_date': '1975-12-31', 'description': 'TOTAL CAPITAL ACCOUNTS', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f4f'), 'mdrm_item': 'RIAD3275', 'description': 'TOTAL CAPITAL ACCOUNTS - PRECEDING YEAR', 'details': {'start_date': '1969-12-31', 'end_date': '1975-12-31', 'description': 'TOTAL CAPITAL ACCOUNTS - PRECEDING YEAR', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f50'), 'mdrm_item': 'RIAD3320', 'description': 'TOTAL COMPONENTS OF OTHER INCREASES AND DECREASES IN UNDIVIDED PROFITS AND CAPITAL RESERVE', 'details': {'start_date': '1976-12-31', 'end_date': '1976-12-31', 'description': 'TOTAL COMPONENTS OF OTHER INCREASES AND DECREASES IN UNDIVIDED PROFITS AND CAPITAL RESERVE', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f51'), 'mdrm_item': 'RIAD3321', 'description': 'NET DEFINITIONAL ADJUSTMENTS', 'details': {'start_date': '1976-12-31', 'end_date': '1976-12-31', 'description': 'NET DEFINITIONAL ADJUSTMENTS', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f52'), 'mdrm_item': 'RIAD3322', 'description': 'CONTINGENCY PORTION OF DECEMBER 31, 1975 IRS RESERVE FOR BAD DEBTS', 'details': {'start_date': '1976-12-31', 'end_date': '1976-12-31', 'description': 'CONTINGENCY PORTION OF DECEMBER 31, 1975 IRS RESERVE FOR BAD DEBTS', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f53'), 'mdrm_item': 'RIAD3323', 'description': 'INTEREST COLLECTED BUT NOT EARNED', 'details': {'start_date': '1976-12-31', 'end_date': '1976-12-31', 'description': 'INTEREST COLLECTED BUT NOT EARNED', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f54'), 'mdrm_item': 'RIAD3324', 'description': 'NET NON-DEFINITIONAL ADJUSTMENTS', 'details': {'start_date': '1976-12-31', 'end_date': '1976-12-31', 'description': 'NET NON-DEFINITIONAL ADJUSTMENTS', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f55'), 'mdrm_item': 'RIAD3325', 'description': 'ACCRETION OF DISCOUNT', 'details': {'start_date': '1976-12-31', 'end_date': '1976-12-31', 'description': 'ACCRETION OF DISCOUNT', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f56'), 'mdrm_item': 'RIAD3326', 'description': 'OTHER INCREASES', 'details': {'start_date': '1976-12-31', 'end_date': '1976-12-31', 'description': 'OTHER INCREASES', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f57'), 'mdrm_item': 'RIAD3327', 'description': 'OTHER DECREASES', 'details': {'start_date': '1976-12-31', 'end_date': '1976-12-31', 'description': 'OTHER DECREASES', 'confidential': 'No', 'reporting_forms': 'FFIEC 011'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f58'), 'mdrm_item': 'RIAD3521', 'description': 'REALIZED GAINS (LOSSES) ON HELD-TO-MATURITY SECURITIES', 'details': {'start_date': '1994-03-31', 'end_date': '9999-12-31', 'description': 'REALIZED GAINS (LOSSES) ON HELD-TO-MATURITY SECURITIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f59'), 'mdrm_item': 'RIAD3582', 'description': 'CHARGE-OFFS ON CONSTRUCTION AND LAND DEVELOPMENT LOANS', 'details': {'start_date': '1991-03-31', 'end_date': '2007-12-31', 'description': 'CHARGE-OFFS ON CONSTRUCTION AND LAND DEVELOPMENT LOANS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f5a'), 'mdrm_item': 'RIAD3582', 'description': 'CHARGE-OFFS ON CONSTRUCTION AND LAND DEVELOPMENT LOANS', 'details': {'start_date': '2008-03-31', 'end_date': '9999-12-31', 'description': 'CHARGE-OFFS ON CONSTRUCTION AND LAND DEVELOPMENT LOANS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f5b'), 'mdrm_item': 'RIAD3583', 'description': 'RECOVERIES ON CONSTRUCTION AND LAND DEVELOPMENT LOANS', 'details': {'start_date': '1991-03-31', 'end_date': '2007-12-31', 'description': 'RECOVERIES ON CONSTRUCTION AND LAND DEVELOPMENT LOANS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f5c'), 'mdrm_item': 'RIAD3583', 'description': 'RECOVERIES ON CONSTRUCTION AND LAND DEVELOPMENT LOANS', 'details': {'start_date': '2008-03-31', 'end_date': '9999-12-31', 'description': 'RECOVERIES ON CONSTRUCTION AND LAND DEVELOPMENT LOANS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f5d'), 'mdrm_item': 'RIAD3584', 'description': 'CHARGE-OFFS ON LOANS SECURED BY FARMLAND', 'details': {'start_date': '1991-03-31', 'end_date': '9999-12-31', 'description': 'CHARGE-OFFS ON LOANS SECURED BY FARMLAND', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f5e'), 'mdrm_item': 'RIAD3585', 'description': 'RECOVERIES ON LOANS SECURED BY FARMLAND', 'details': {'start_date': '1991-03-31', 'end_date': '9999-12-31', 'description': 'RECOVERIES ON LOANS SECURED BY FARMLAND', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f5f'), 'mdrm_item': 'RIAD3588', 'description': 'CHARGE-OFFS ON LOANS SECURED BY MULTIFAMILY (5 OR MORE) RESIDENTIAL PROPERTIES', 'details': {'start_date': '1991-03-31', 'end_date': '9999-12-31', 'description': 'CHARGE-OFFS ON LOANS SECURED BY MULTIFAMILY (5 OR MORE) RESIDENTIAL PROPERTIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f60'), 'mdrm_item': 'RIAD3589', 'description': 'RECOVERIES ON LOANS SECURED BY MULTIFAMILY (5 OR MORE) RESIDENTIAL PROPERTIES', 'details': {'start_date': '1991-03-31', 'end_date': '9999-12-31', 'description': 'RECOVERIES ON LOANS SECURED BY MULTIFAMILY (5 OR MORE) RESIDENTIAL PROPERTIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f61'), 'mdrm_item': 'RIAD3590', 'description': 'CHARGE-OFFS ON LOANS SECURED BY NONFARM NONRESIDENTIAL PROPERTIES', 'details': {'start_date': '1991-03-31', 'end_date': '2007-12-31', 'description': 'CHARGE-OFFS ON LOANS SECURED BY NONFARM NONRESIDENTIAL PROPERTIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f62'), 'mdrm_item': 'RIAD3590', 'description': 'CHARGE-OFFS ON LOANS SECURED BY NONFARM NONRESIDENTIAL PROPERTIES', 'details': {'start_date': '2008-03-31', 'end_date': '9999-12-31', 'description': 'CHARGE-OFFS ON LOANS SECURED BY NONFARM NONRESIDENTIAL PROPERTIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f63'), 'mdrm_item': 'RIAD3591', 'description': 'RECOVERIES ON LOANS SECURED BY NONFARM NONRESIDENTIAL PROPERTIES', 'details': {'start_date': '1991-03-31', 'end_date': '2007-12-31', 'description': 'RECOVERIES ON LOANS SECURED BY NONFARM NONRESIDENTIAL PROPERTIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f64'), 'mdrm_item': 'RIAD3591', 'description': 'RECOVERIES ON LOANS SECURED BY NONFARM NONRESIDENTIAL PROPERTIES', 'details': {'start_date': '2008-03-31', 'end_date': '9999-12-31', 'description': 'RECOVERIES ON LOANS SECURED BY NONFARM NONRESIDENTIAL PROPERTIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f65'), 'mdrm_item': 'RIAD3657', 'description': 'INTEREST AND DIVIDEND INCOME ON OTHER DOMESTIC DEBT SECURITIES', 'details': {'start_date': '1989-03-31', 'end_date': '2000-12-31', 'description': 'INTEREST AND DIVIDEND INCOME ON OTHER DOMESTIC DEBT SECURITIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f66'), 'mdrm_item': 'RIAD3658', 'description': 'INTEREST AND DIVIDEND INCOME ON FOREIGN DEBT SECURITIES', 'details': {'start_date': '1989-03-31', 'end_date': '2000-12-31', 'description': 'INTEREST AND DIVIDEND INCOME ON FOREIGN DEBT SECURITIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f67'), 'mdrm_item': 'RIAD3659', 'description': 'INTEREST AND DIVIDEND INCOME ON EQUITY SECURITIES', 'details': {'start_date': '1989-03-31', 'end_date': '2000-12-31', 'description': 'INTEREST AND DIVIDEND INCOME ON EQUITY SECURITIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f68'), 'mdrm_item': 'RIAD3660', 'description': 'INTEREST AND DIVIDEND INCOME ON U.S. GOVERNMENT SECURITIES AND OTHER DEBT SECURITIES', 'details': {'start_date': '1989-03-31', 'end_date': '2000-12-31', 'description': 'INTEREST AND DIVIDEND INCOME ON U.S. GOVERNMENT SECURITIES AND OTHER DEBT SECURITIES', 'confidential': 'No', 'reporting_forms': 'FFIEC 034'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f69'), 'mdrm_item': 'RIAD4000', 'description': 'TOTAL INTEREST AND NONINTEREST INCOME', 'details': {'start_date': '1969-12-31', 'end_date': '9999-12-31', 'description': 'TOTAL INTEREST AND NONINTEREST INCOME', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f6a'), 'mdrm_item': 'RIAD4008', 'description': 'INTEREST AND FEES ON REAL ESTATE LOANS', 'details': {'start_date': '1979-06-30', 'end_date': '1985-12-31', 'description': 'INTEREST AND FEES ON REAL ESTATE LOANS', 'confidential': 'No', 'reporting_forms': 'FDIC 8040/51'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f6b'), 'mdrm_item': 'RIAD4009', 'description': 'INTEREST AND FEES ON OTHER LOANS', 'details': {'start_date': '1979-06-30', 'end_date': '1985-12-31', 'description': 'INTEREST AND FEES ON OTHER LOANS', 'confidential': 'No', 'reporting_forms': 'FDIC 8040/51'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f6c'), 'mdrm_item': 'RIAD4010', 'description': 'INTEREST AND FEE INCOME ON LOANS, TOTAL', 'details': {'start_date': '1969-12-31', 'end_date': '2000-12-31', 'description': 'INTEREST AND FEE INCOME ON LOANS, TOTAL', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f6d'), 'mdrm_item': 'RIAD4010', 'description': 'INTEREST AND FEE INCOME ON LOANS, TOTAL', 'details': {'start_date': '2001-03-31', 'end_date': '9999-12-31', 'description': 'INTEREST AND FEE INCOME ON LOANS, TOTAL', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f6e'), 'mdrm_item': 'RIAD4011', 'description': 'INTEREST AND FEE INCOME ON LOANS SECURED BY REAL ESTATE', 'details': {'start_date': '1984-03-31', 'end_date': '2007-12-31', 'description': 'INTEREST AND FEE INCOME ON LOANS SECURED BY REAL ESTATE', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f6f'), 'mdrm_item': 'RIAD4011', 'description': 'INTEREST AND FEE INCOME ON LOANS SECURED BY REAL ESTATE', 'details': {'start_date': '2008-03-31', 'end_date': '9999-12-31', 'description': 'INTEREST AND FEE INCOME ON LOANS SECURED BY REAL ESTATE', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f70'), 'mdrm_item': 'RIAD4012', 'description': 'INTEREST AND FEE INCOME ON COMMERCIAL AND INDUSTRIAL LOANS', 'details': {'start_date': '1984-03-31', 'end_date': '9999-12-31', 'description': 'INTEREST AND FEE INCOME ON COMMERCIAL AND INDUSTRIAL LOANS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f71'), 'mdrm_item': 'RIAD4013', 'description': 'INTEREST AND FEE INCOME ON LOANS TO INDIVIDUALS, FOR HOUSEHOLD, FAMILY, AND OTHER PERSONAL EXPENDITURES', 'details': {'start_date': '1984-03-31', 'end_date': '9999-12-31', 'description': 'INTEREST AND FEE INCOME ON LOANS TO INDIVIDUALS, FOR HOUSEHOLD, FAMILY, AND OTHER PERSONAL EXPENDITURES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f72'), 'mdrm_item': 'RIAD4019', 'description': 'INTEREST AND FEE INCOME ON LOANS TO DEPOSITORY INSTITUTIONS IN DOMESTIC OFFICES', 'details': {'start_date': '1984-03-31', 'end_date': '2000-12-31', 'description': 'INTEREST AND FEE INCOME ON LOANS TO DEPOSITORY INSTITUTIONS IN DOMESTIC OFFICES', 'confidential': 'No', 'reporting_forms': 'FFIEC 031'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f73'), 'mdrm_item': 'RIAD4020', 'description': 'INTEREST INCOME ON FEDERAL FUNDS SOLD AND SECURITIES PURCHASED UNDER AGREEMENTS TO RESELL', 'details': {'start_date': '1969-12-31', 'end_date': '9999-12-31', 'description': 'INTEREST INCOME ON FEDERAL FUNDS SOLD AND SECURITIES PURCHASED UNDER AGREEMENTS TO RESELL', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f74'), 'mdrm_item': 'RIAD4021', 'description': 'NET GAIN (LOSS) ON FOREIGN EXCHANGE TRANSACTIONS', 'details': {'start_date': '1978-12-31', 'end_date': '1997-06-30', 'description': 'NET GAIN (LOSS) ON FOREIGN EXCHANGE TRANSACTIONS', 'confidential': 'No', 'reporting_forms': 'FR 2886b'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f75'), 'mdrm_item': 'RIAD4022', 'description': 'DIVIDENDS ON STOCK - NON-AFFILIATED COMPANIES', 'details': {'start_date': '1978-12-31', 'end_date': '1997-06-30', 'description': 'DIVIDENDS ON STOCK - NON-AFFILIATED COMPANIES', 'confidential': 'No', 'reporting_forms': 'FR 2886b'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f76'), 'mdrm_item': 'RIAD4023', 'description': 'EQUITY IN UNDISTRIBUTED NET INCOME - NON-AFFILIATED COMPANIES', 'details': {'start_date': '1978-12-31', 'end_date': '1997-06-30', 'description': 'EQUITY IN UNDISTRIBUTED NET INCOME - NON-AFFILIATED COMPANIES', 'confidential': 'No', 'reporting_forms': 'FR 2886b'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f77'), 'mdrm_item': 'RIAD4024', 'description': 'INTEREST AND FEE INCOME ON LOANS TO FINANCE AGRICULTURAL PRODUCTION AND OTHER LOANS TO FARMERS IN DOMESTIC OFFICES', 'details': {'start_date': '1984-03-31', 'end_date': '9999-12-31', 'description': 'INTEREST AND FEE INCOME ON LOANS TO FINANCE AGRICULTURAL PRODUCTION AND OTHER LOANS TO FARMERS IN DOMESTIC OFFICES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f78'), 'mdrm_item': 'RIAD4025', 'description': 'TOTAL INTEREST ON BONDS, NOTES, AND DEBENTURES', 'details': {'start_date': '1976-03-31', 'end_date': '1997-06-30', 'description': 'TOTAL INTEREST ON BONDS, NOTES, AND DEBENTURES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f79'), 'mdrm_item': 'RIAD4026', 'description': 'INTEREST AND FEE INCOME ON ACCEPTANCES OF OTHER BANKS IN DOMESTIC OFFICES', 'details': {'start_date': '1984-03-31', 'end_date': '2000-12-31', 'description': 'INTEREST AND FEE INCOME ON ACCEPTANCES OF OTHER BANKS IN DOMESTIC OFFICES', 'confidential': 'No', 'reporting_forms': 'FFIEC 031'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f7a'), 'mdrm_item': 'RIAD4027', 'description': 'INTEREST AND DIVIDEND INCOME ON U.S. TREASURY SECURITIES AND U.S. GOVERNMENT AGENCY AND CORPORATION OBLIGATIONS', 'details': {'start_date': '1969-12-31', 'end_date': '2000-12-31', 'description': 'INTEREST AND DIVIDEND INCOME ON U.S. TREASURY SECURITIES AND U.S. GOVERNMENT AGENCY AND CORPORATION OBLIGATIONS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f7b'), 'mdrm_item': 'RIAD4028', 'description': 'INTEREST ON BALANCES WITH AFFILIATES', 'details': {'start_date': '1978-12-31', 'end_date': '9999-12-31', 'description': 'INTEREST ON BALANCES WITH AFFILIATES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f7c'), 'mdrm_item': 'RIAD4029', 'description': 'OTHER INCOME FROM AFFILIATES', 'details': {'start_date': '1978-12-31', 'end_date': '1990-12-31', 'description': 'OTHER INCOME FROM AFFILIATES', 'confidential': 'No', 'reporting_forms': 'FR 2886b'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f7d'), 'mdrm_item': 'RIAD4030', 'description': 'INTEREST ON U.S. TREASURY SECURITIES', 'details': {'start_date': '1969-12-31', 'end_date': '1983-12-31', 'description': 'INTEREST ON U.S. TREASURY SECURITIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f7e'), 'mdrm_item': 'RIAD4035', 'description': 'INTEREST ON CORPORATE BONDS', 'details': {'start_date': '1979-06-30', 'end_date': '1985-12-31', 'description': 'INTEREST ON CORPORATE BONDS', 'confidential': 'No', 'reporting_forms': 'FDIC 8040/51'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f7f'), 'mdrm_item': 'RIAD4040', 'description': 'INTEREST ON OBLIGATIONS OF OTHER U.S. GOVERNMENT AGENCIES AND CORPORATIONS', 'details': {'start_date': '1969-12-31', 'end_date': '1983-12-31', 'description': 'INTEREST ON OBLIGATIONS OF OTHER U.S. GOVERNMENT AGENCIES AND CORPORATIONS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f80'), 'mdrm_item': 'RIAD4042', 'description': 'GROSS INCOME FROM REAL ESTATE OWNED OPERATIONS', 'details': {'start_date': '2001-03-31', 'end_date': '9999-12-31', 'description': 'GROSS INCOME FROM REAL ESTATE OWNED OPERATIONS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f81'), 'mdrm_item': 'RIAD4050', 'description': 'INTEREST ON OBLIGATIONS OF STATES AND POLITICAL SUBDIVISIONS', 'details': {'start_date': '1969-12-31', 'end_date': '1985-12-31', 'description': 'INTEREST ON OBLIGATIONS OF STATES AND POLITICAL SUBDIVISIONS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f82'), 'mdrm_item': 'RIAD4054', 'description': 'CREDIT CARDS AND RELATED PLANS', 'details': {'start_date': '1984-03-31', 'end_date': '2000-12-31', 'description': 'CREDIT CARDS AND RELATED PLANS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f83'), 'mdrm_item': 'RIAD4055', 'description': 'OTHER LOANS TO INDIVIDUALS FOR HOUSEHOLD, FAMILY, AND OTHER PERSONAL EXPENDITURES', 'details': {'start_date': '1984-03-31', 'end_date': '2000-12-31', 'description': 'OTHER LOANS TO INDIVIDUALS FOR HOUSEHOLD, FAMILY, AND OTHER PERSONAL EXPENDITURES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f84'), 'mdrm_item': 'RIAD4056', 'description': 'INTEREST AND FEE INCOME ON LOANS TO FOREIGN GOVERNMENTS AND OFFICIAL INSTITUTIONS IN DOMESTIC OFFICES', 'details': {'start_date': '1984-03-31', 'end_date': '2016-12-31', 'description': 'INTEREST AND FEE INCOME ON LOANS TO FOREIGN GOVERNMENTS AND OFFICIAL INSTITUTIONS IN DOMESTIC OFFICES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f85'), 'mdrm_item': 'RIAD4057', 'description': 'INTEREST AND FEE INCOME ON OBLIGATIONS (OTHER THAN SECURITIES) OF STATES AND POLITICAL SUBDIVISIONS IN THE U.S. IN DOMESTIC OFFICES', 'details': {'start_date': '1984-03-31', 'end_date': '1986-12-31', 'description': 'INTEREST AND FEE INCOME ON OBLIGATIONS (OTHER THAN SECURITIES) OF STATES AND POLITICAL SUBDIVISIONS IN THE U.S. IN DOMESTIC OFFICES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f86'), 'mdrm_item': 'RIAD4057', 'description': 'INTEREST AND FEE INCOME ON OBLIGATIONS (OTHER THAN SECURITIES) OF STATES AND POLITICAL SUBDIVISIONS IN THE U.S. IN DOMESTIC OFFICES', 'details': {'start_date': '1987-03-31', 'end_date': '2000-12-31', 'description': 'INTEREST AND FEE INCOME ON OBLIGATIONS (OTHER THAN SECURITIES) OF STATES AND POLITICAL SUBDIVISIONS IN THE U.S. IN DOMESTIC OFFICES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f87'), 'mdrm_item': 'RIAD4058', 'description': 'INTEREST AND FEE INCOME ON ALL OTHER LOANS IN DOMESTIC OFFICES', 'details': {'start_date': '1984-03-31', 'end_date': '9999-12-31', 'description': 'INTEREST AND FEE INCOME ON ALL OTHER LOANS IN DOMESTIC OFFICES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f88'), 'mdrm_item': 'RIAD4059', 'description': 'INTEREST AND FEE INCOME ON LOANS IN FOREIGN OFFICES, EDGE AND AGREEMENT SUBSIDIARIES, AND IBFS', 'details': {'start_date': '1984-03-31', 'end_date': '9999-12-31', 'description': 'INTEREST AND FEE INCOME ON LOANS IN FOREIGN OFFICES, EDGE AND AGREEMENT SUBSIDIARIES, AND IBFS', 'confidential': 'No', 'reporting_forms': 'FFIEC 031'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f89'), 'mdrm_item': 'RIAD4060', 'description': 'INTEREST ON OTHER SECURITIES', 'details': {'start_date': '1969-12-31', 'end_date': '1983-12-31', 'description': 'INTEREST ON OTHER SECURITIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f8a'), 'mdrm_item': 'RIAD4060', 'description': 'INTEREST ON OTHER SECURITIES', 'details': {'start_date': '2001-03-31', 'end_date': '9999-12-31', 'description': 'INTEREST ON OTHER SECURITIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f8b'), 'mdrm_item': 'RIAD4061', 'description': 'INTEREST ON OTHER BONDS, NOTES, AND DEBENTURES', 'details': {'start_date': '1976-03-31', 'end_date': '1985-12-31', 'description': 'INTEREST ON OTHER BONDS, NOTES, AND DEBENTURES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f8c'), 'mdrm_item': 'RIAD4063', 'description': 'DIVIDENDS ON STOCKS', 'details': {'start_date': '1976-03-31', 'end_date': '1985-12-31', 'description': 'DIVIDENDS ON STOCKS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f8d'), 'mdrm_item': 'RIAD4065', 'description': 'INCOME FROM LEASE FINANCING RECEIVABLES', 'details': {'start_date': '1976-03-31', 'end_date': '1986-12-31', 'description': 'INCOME FROM LEASE FINANCING RECEIVABLES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f8e'), 'mdrm_item': 'RIAD4065', 'description': 'INCOME FROM LEASE FINANCING RECEIVABLES', 'details': {'start_date': '1987-03-31', 'end_date': '2000-12-31', 'description': 'INCOME FROM LEASE FINANCING RECEIVABLES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f8f'), 'mdrm_item': 'RIAD4065', 'description': 'INCOME FROM LEASE FINANCING RECEIVABLES', 'details': {'start_date': '2001-03-31', 'end_date': '9999-12-31', 'description': 'INCOME FROM LEASE FINANCING RECEIVABLES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f90'), 'mdrm_item': 'RIAD4066', 'description': 'INTEREST AND DIVIDEND INCOME ON SECURITIES ISSUED BY STATES AND POLITICAL SUBDIVISIONS IN THE U.S.', 'details': {'start_date': '1984-03-31', 'end_date': '1986-12-31', 'description': 'INTEREST AND DIVIDEND INCOME ON SECURITIES ISSUED BY STATES AND POLITICAL SUBDIVISIONS IN THE U.S.', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f91'), 'mdrm_item': 'RIAD4066', 'description': 'INTEREST AND DIVIDEND INCOME ON SECURITIES ISSUED BY STATES AND POLITICAL SUBDIVISIONS IN THE U.S.', 'details': {'start_date': '1987-03-31', 'end_date': '2000-12-31', 'description': 'INTEREST AND DIVIDEND INCOME ON SECURITIES ISSUED BY STATES AND POLITICAL SUBDIVISIONS IN THE U.S.', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f92'), 'mdrm_item': 'RIAD4067', 'description': 'INTEREST AND DIVIDEND INCOME ON OTHER DOMESTIC SECURITIES (DEBT AND EQUITY)', 'details': {'start_date': '1984-03-31', 'end_date': '1988-12-31', 'description': 'INTEREST AND DIVIDEND INCOME ON OTHER DOMESTIC SECURITIES (DEBT AND EQUITY)', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f93'), 'mdrm_item': 'RIAD4068', 'description': 'INTEREST AND DIVIDEND INCOME ON FOREIGN SECURITIES (DEBT AND EQUITY)', 'details': {'start_date': '1984-03-31', 'end_date': '1988-12-31', 'description': 'INTEREST AND DIVIDEND INCOME ON FOREIGN SECURITIES (DEBT AND EQUITY)', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f94'), 'mdrm_item': 'RIAD4069', 'description': 'INTEREST INCOME FROM TRADING ASSETS', 'details': {'start_date': '1984-03-31', 'end_date': '9999-12-31', 'description': 'INTEREST INCOME FROM TRADING ASSETS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f95'), 'mdrm_item': 'RIAD4070', 'description': 'INCOME FROM FIDUCIARY ACTIVITIES', 'details': {'start_date': '1969-12-31', 'end_date': '9999-12-31', 'description': 'INCOME FROM FIDUCIARY ACTIVITIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f96'), 'mdrm_item': 'RIAD4072', 'description': 'INTEREST EXPENSE ON MORTGAGE INDEBTEDNESS AND OBLIGATIONS UNDER CAPITALIZED LEASES', 'details': {'start_date': '1984-03-31', 'end_date': '1996-12-31', 'description': 'INTEREST EXPENSE ON MORTGAGE INDEBTEDNESS AND OBLIGATIONS UNDER CAPITALIZED LEASES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f97'), 'mdrm_item': 'RIAD4073', 'description': 'TOTAL INTEREST EXPENSE', 'details': {'start_date': '1984-03-31', 'end_date': '9999-12-31', 'description': 'TOTAL INTEREST EXPENSE', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f98'), 'mdrm_item': 'RIAD4074', 'description': 'NET INTEREST INCOME', 'details': {'start_date': '1984-03-31', 'end_date': '9999-12-31', 'description': 'NET INTEREST INCOME', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f99'), 'mdrm_item': 'RIAD4075', 'description': 'NONINTEREST INCOME ON TRADING GAINS (LOSSES) AND FEES FROM FOREIGN EXCHANGE TRANSACTIONS', 'details': {'start_date': '1984-03-31', 'end_date': '1995-12-31', 'description': 'NONINTEREST INCOME ON TRADING GAINS (LOSSES) AND FEES FROM FOREIGN EXCHANGE TRANSACTIONS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f9a'), 'mdrm_item': 'RIAD4076', 'description': 'NONINTEREST INCOME ON OTHER FOREIGN TRANSACTION GAINS (LOSSES)', 'details': {'start_date': '1984-03-31', 'end_date': '1996-12-31', 'description': 'NONINTEREST INCOME ON OTHER FOREIGN TRANSACTION GAINS (LOSSES)', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f9b'), 'mdrm_item': 'RIAD4077', 'description': 'NONINTEREST INCOME ON OTHER GAINS (LOSSES) AND FEES FROM TRADING ASSETS AND LIABILITIES', 'details': {'start_date': '1984-03-31', 'end_date': '1995-12-31', 'description': 'NONINTEREST INCOME ON OTHER GAINS (LOSSES) AND FEES FROM TRADING ASSETS AND LIABILITIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f9c'), 'mdrm_item': 'RIAD4077', 'description': 'NONINTEREST INCOME ON OTHER GAINS (LOSSES) AND FEES FROM TRADING ASSETS AND LIABILITIES', 'details': {'start_date': '1997-09-30', 'end_date': '9999-12-31', 'description': 'NONINTEREST INCOME ON OTHER GAINS (LOSSES) AND FEES FROM TRADING ASSETS AND LIABILITIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f9d'), 'mdrm_item': 'RIAD4078', 'description': 'OTHER NONINTEREST INCOME', 'details': {'start_date': '1984-03-31', 'end_date': '1990-12-31', 'description': 'OTHER NONINTEREST INCOME', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f9e'), 'mdrm_item': 'RIAD4078', 'description': 'OTHER NONINTEREST INCOME', 'details': {'start_date': '1991-03-31', 'end_date': '2000-12-31', 'description': 'OTHER NONINTEREST INCOME', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7f9f'), 'mdrm_item': 'RIAD4079', 'description': 'TOTAL NONINTEREST INCOME', 'details': {'start_date': '1984-03-31', 'end_date': '9999-12-31', 'description': 'TOTAL NONINTEREST INCOME', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7fa0'), 'mdrm_item': 'RIAD4080', 'description': 'SERVICE CHARGES ON DEPOSIT ACCOUNTS IN DOMESTIC OFFICES', 'details': {'start_date': '1969-12-31', 'end_date': '9999-12-31', 'description': 'SERVICE CHARGES ON DEPOSIT ACCOUNTS IN DOMESTIC OFFICES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7fa1'), 'mdrm_item': 'RIAD4090', 'description': 'OTHER SERVICE CHARGES, COMMISSIONS, AND FEES', 'details': {'start_date': '1969-12-31', 'end_date': '9999-12-31', 'description': 'OTHER SERVICE CHARGES, COMMISSIONS, AND FEES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb7fa2'), 'mdrm_item': 'RIAD4091', 'description': 'GAINS (LOSSES) ON SECURITIES NOT HELD IN TRADING ACCOUNTS', 'details': {'start_date': '1984-03-31', 'end_date': '9999-12-31', 'description': 'GAINS (LOSSES) ON SECURITIES NOT HELD IN TRADING ACCOUNTS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# ...
# {'_id': ObjectId('5946004ddbc5544250fb81f8'), 'mdrm_item': 'RIADFT30', 'description': 'DISCONTINUED OPERATIONS AND APPLICABLE INCOME TAX EFFECT, APPLICABLE INCOME TAX EFFECT, FIELD 1', 'details': {'start_date': '2016-09-30', 'end_date': '9999-12-31', 'description': 'DISCONTINUED OPERATIONS AND APPLICABLE INCOME TAX EFFECT, APPLICABLE INCOME TAX EFFECT, FIELD 1', 'confidential': 'No', 'reporting_forms': nan}}
# {'_id': ObjectId('5946004ddbc5544250fb81f9'), 'mdrm_item': 'RIADFT31', 'description': 'DISCONTINUED OPERATIONS AND APPLICABLE INCOME TAX EFFECT, APPLICABLE INCOME TAX EFFECT, FIELD 1', 'details': {'start_date': '2016-09-30', 'end_date': '9999-12-31', 'description': 'DISCONTINUED OPERATIONS AND APPLICABLE INCOME TAX EFFECT, APPLICABLE INCOME TAX EFFECT, FIELD 1', 'confidential': 'No', 'reporting_forms': nan}}
# {'_id': ObjectId('5946004ddbc5544250fb81fa'), 'mdrm_item': 'RIADFT32', 'description': 'DISCONTINUED OPERATIONS AND APPLICABLE INCOME TAX EFFECT, APPLICABLE INCOME TAX EFFECT, FIELD 2', 'details': {'start_date': '2016-09-30', 'end_date': '9999-12-31', 'description': 'DISCONTINUED OPERATIONS AND APPLICABLE INCOME TAX EFFECT, APPLICABLE INCOME TAX EFFECT, FIELD 2', 'confidential': 'No', 'reporting_forms': nan}}
# {'_id': ObjectId('5946004ddbc5544250fb81fb'), 'mdrm_item': 'RIADFT36', 'description': "IMPACT ON TRADING REVENUE OF CHANGES IN THE CREDITWORTHINESS OF THE BANK'S DERIVATIVES COUNTERPARTIES ON THE BANK'S DERIVATIVE ASSETS, GROSS CREDIT VALUATION ADJUSTMENT CVA", 'details': {'start_date': '2017-03-31', 'end_date': '9999-12-31', 'description': "IMPACT ON TRADING REVENUE OF CHANGES IN THE CREDITWORTHINESS OF THE BANK'S DERIVATIVES COUNTERPARTIES ON THE BANK'S DERIVATIVE ASSETS, GROSS CREDIT VALUATION ADJUSTMENT CVA", 'confidential': 'No', 'reporting_forms': nan}}
# {'_id': ObjectId('5946004ddbc5544250fb81fc'), 'mdrm_item': 'RIADFT37', 'description': "IMPACT ON TRADING REVENUE OF CHANGES IN THE CREDITWORTHINESS OF THE BANK'S DERIVATIVES COUNTERPARTIES ON THE BANK'S DERIVATIVE ASSETS, CVA HEDGE", 'details': {'start_date': '2017-03-31', 'end_date': '9999-12-31', 'description': "IMPACT ON TRADING REVENUE OF CHANGES IN THE CREDITWORTHINESS OF THE BANK'S DERIVATIVES COUNTERPARTIES ON THE BANK'S DERIVATIVE ASSETS, CVA HEDGE", 'confidential': 'No', 'reporting_forms': nan}}
# {'_id': ObjectId('5946004ddbc5544250fb81fd'), 'mdrm_item': 'RIADFT38', 'description': "IMPACT ON TRADING REVENUE OF CHANGES IN THE CREDITWORTHINESS OF THE BANK ON THE BANK'S DERIVATIVES LIABILITIES, GROSS DEBIT VALUATION ADJUSTMENT DVA", 'details': {'start_date': '2017-03-31', 'end_date': '9999-12-31', 'description': "IMPACT ON TRADING REVENUE OF CHANGES IN THE CREDITWORTHINESS OF THE BANK ON THE BANK'S DERIVATIVES LIABILITIES, GROSS DEBIT VALUATION ADJUSTMENT DVA", 'confidential': 'No', 'reporting_forms': nan}}
# {'_id': ObjectId('5946004ddbc5544250fb81fe'), 'mdrm_item': 'RIADFT39', 'description': "IMPACT ON TRADING REVENUE OF CHANGES IN THE CREDITWORTHINESS OF THE BANK ON THE BANK'S DERIVATIVE LIABILITIES, DVA HEDGE", 'details': {'start_date': '2017-03-31', 'end_date': '9999-12-31', 'description': "IMPACT ON TRADING REVENUE OF CHANGES IN THE CREDITWORTHINESS OF THE BANK ON THE BANK'S DERIVATIVE LIABILITIES, DVA HEDGE", 'confidential': 'No', 'reporting_forms': nan}}
# {'_id': ObjectId('5946004ddbc5544250fb81ff'), 'mdrm_item': 'RIADFT40', 'description': 'GROSS TRADING REVENUE, BEFORE INCLUDING POSITIVE OR NEGATIVE NET CVA AND NET DVA', 'details': {'start_date': '2017-03-31', 'end_date': '9999-12-31', 'description': 'GROSS TRADING REVENUE, BEFORE INCLUDING POSITIVE OR NEGATIVE NET CVA AND NET DVA', 'confidential': 'No', 'reporting_forms': nan}}
# {'_id': ObjectId('5946004ddbc5544250fb8200'), 'mdrm_item': 'RIADG103', 'description': 'LESS: NET INCOME (LOSS) ATTRIBUTABLE TO NONCONTROLLING (MINORITY) INTERESTS', 'details': {'start_date': '2009-03-31', 'end_date': '9999-12-31', 'description': 'LESS: NET INCOME (LOSS) ATTRIBUTABLE TO NONCONTROLLING (MINORITY) INTERESTS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb8201'), 'mdrm_item': 'RIADG104', 'description': 'NET INCOME (LOSS) ATTRIBUTABLE TO BANK AND NONCONTROLLING MINORITY INTERESTS', 'details': {'start_date': '2009-03-31', 'end_date': '9999-12-31', 'description': 'NET INCOME (LOSS) ATTRIBUTABLE TO BANK AND NONCONTROLLING MINORITY INTERESTS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb8202'), 'mdrm_item': 'RIADG377', 'description': 'CONSTRUCTION, LAND DEVELOPMENT, AND OTHER LAND LOANS IN DOMESTIC OFFICES WITH INTEREST RESERVES: AMOUNT OF INTEREST CAPITALIZED FROM INTEREST RESERVES ON CONSTRUCTION, LAND DEVELOPMENT, AND OTHER LAND LOANS THAT IS INCLUDED IN INTEREST AND FEE INCOME ON LOANS DURING THE QUARTER (INCLUDED IN SCHEDULE RI, ITEM 1.A.(1)(A)(2))', 'details': {'start_date': '2009-06-30', 'end_date': '9999-12-31', 'description': 'CONSTRUCTION, LAND DEVELOPMENT, AND OTHER LAND LOANS IN DOMESTIC OFFICES WITH INTEREST RESERVES: AMOUNT OF INTEREST CAPITALIZED FROM INTEREST RESERVES ON CONSTRUCTION, LAND DEVELOPMENT, AND OTHER LAND LOANS THAT IS INCLUDED IN INTEREST AND FEE INCOME ON LOANS DURING THE QUARTER (INCLUDED IN SCHEDULE RI, ITEM 1.A.(1)(A)(2))', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb8203'), 'mdrm_item': 'RIADG894', 'description': 'CUMULATIVE EFFECT OF THE INITIAL APPLICATION OF FSP FAS 115-2 ON OTHER-THAN-TEMPORARY IMPAIRMENT', 'details': {'start_date': '2009-06-30', 'end_date': '2009-12-31', 'description': 'CUMULATIVE EFFECT OF THE INITIAL APPLICATION OF FSP FAS 115-2 ON OTHER-THAN-TEMPORARY IMPAIRMENT', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb8204'), 'mdrm_item': 'RIADGW44', 'description': 'OTHER INTEREST EXPENSE', 'details': {'start_date': '2017-03-31', 'end_date': '9999-12-31', 'description': 'OTHER INTEREST EXPENSE', 'confidential': 'No', 'reporting_forms': nan}}
# {'_id': ObjectId('5946004ddbc5544250fb8205'), 'mdrm_item': 'RIADGW64', 'description': 'DISCONTINUED OPERATIONS, NET OF APPLICABLE INCOME TAXES, IN FOREIGN OFFICES', 'details': {'start_date': '2016-09-30', 'end_date': '9999-12-31', 'description': 'DISCONTINUED OPERATIONS, NET OF APPLICABLE INCOME TAXES, IN FOREIGN OFFICES', 'confidential': 'No', 'reporting_forms': 'FFIEC 031'}}
# {'_id': ObjectId('5946004ddbc5544250fb8206'), 'mdrm_item': 'RIADH032', 'description': 'SERVICE CHARGES ON DEPOSITS IN DOMESTIC OFFICE OVERDRAFT RELATED FOR INDIVIDUALS', 'details': {'start_date': '2015-03-31', 'end_date': '9999-12-31', 'description': 'SERVICE CHARGES ON DEPOSITS IN DOMESTIC OFFICE OVERDRAFT RELATED FOR INDIVIDUALS', 'confidential': 'No', 'reporting_forms': nan}}
# {'_id': ObjectId('5946004ddbc5544250fb8207'), 'mdrm_item': 'RIADH033', 'description': 'SERVICE CHARGES ON DEPOSITS IN DOMESTIC OFFICE MAINTENANCE FOR INDIVIDUALS', 'details': {'start_date': '2015-03-31', 'end_date': '9999-12-31', 'description': 'SERVICE CHARGES ON DEPOSITS IN DOMESTIC OFFICE MAINTENANCE FOR INDIVIDUALS', 'confidential': 'No', 'reporting_forms': nan}}
# {'_id': ObjectId('5946004ddbc5544250fb8208'), 'mdrm_item': 'RIADH034', 'description': 'SERVICE CHARGES ON DEPOSITS IN DOMESTIC OFFICE ATM-RELATED FOR INDIVIDUALS', 'details': {'start_date': '2015-03-31', 'end_date': '9999-12-31', 'description': 'SERVICE CHARGES ON DEPOSITS IN DOMESTIC OFFICE ATM-RELATED FOR INDIVIDUALS', 'confidential': 'No', 'reporting_forms': nan}}
# {'_id': ObjectId('5946004ddbc5544250fb8209'), 'mdrm_item': 'RIADH035', 'description': 'SERVICE CHARGES ON DEPOSITS IN DOMESTIC OFFICE ALL OTHER', 'details': {'start_date': '2015-03-31', 'end_date': '9999-12-31', 'description': 'SERVICE CHARGES ON DEPOSITS IN DOMESTIC OFFICE ALL OTHER', 'confidential': 'No', 'reporting_forms': nan}}
# {'_id': ObjectId('5946004ddbc5544250fb820a'), 'mdrm_item': 'RIADH321', 'description': 'AUTHORIZED SIGNATURE', 'details': {'start_date': '2017-03-31', 'end_date': '9999-12-31', 'description': 'AUTHORIZED SIGNATURE', 'confidential': 'No', 'reporting_forms': 'FR 2886b'}}
# {'_id': ObjectId('5946004ddbc5544250fb820b'), 'mdrm_item': 'RIADHK03', 'description': 'INTEREST EXPENSE, INTEREST ON DEPOSITS, NONTRANSACTION ACCOUNTS, TIME DEPOSITS OF 250000 OR LESS', 'details': {'start_date': '2017-03-31', 'end_date': '9999-12-31', 'description': 'INTEREST EXPENSE, INTEREST ON DEPOSITS, NONTRANSACTION ACCOUNTS, TIME DEPOSITS OF 250000 OR LESS', 'confidential': 'No', 'reporting_forms': nan}}
# {'_id': ObjectId('5946004ddbc5544250fb820c'), 'mdrm_item': 'RIADHK04', 'description': 'INTEREST EXPENSE, INTEREST ON DEPOSITS, NONTRANSACTION ACCOUNTS, TIME DEPOSITS OF MORE THAN 250000', 'details': {'start_date': '2017-03-31', 'end_date': '9999-12-31', 'description': 'INTEREST EXPENSE, INTEREST ON DEPOSITS, NONTRANSACTION ACCOUNTS, TIME DEPOSITS OF MORE THAN 250000', 'confidential': 'No', 'reporting_forms': nan}}
# {'_id': ObjectId('5946004ddbc5544250fb820d'), 'mdrm_item': 'RIADJ315', 'description': 'FIDUCIARY AND RELATED SERVICES INCOME-INVESTMENT MANAGEMENT AND INVESTMENT ADVISORY AGENCY ACCOUNTS', 'details': {'start_date': '2009-12-31', 'end_date': '9999-12-31', 'description': 'FIDUCIARY AND RELATED SERVICES INCOME-INVESTMENT MANAGEMENT AND INVESTMENT ADVISORY AGENCY ACCOUNTS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb820e'), 'mdrm_item': 'RIADJ316', 'description': 'FIDUCIARY AND RELATED SERVICES INCOME-FOUNDATION AND ENDOWMENT TRUST AND AGENCY ACCOUNTS', 'details': {'start_date': '2009-12-31', 'end_date': '9999-12-31', 'description': 'FIDUCIARY AND RELATED SERVICES INCOME-FOUNDATION AND ENDOWMENT TRUST AND AGENCY ACCOUNTS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb820f'), 'mdrm_item': 'RIADJ319', 'description': 'TOTAL OTHER-THAN-TEMPORARY IMPAIRMENT (OTTI) LOSSES', 'details': {'start_date': '2010-03-31', 'end_date': '2016-12-31', 'description': 'TOTAL OTHER-THAN-TEMPORARY IMPAIRMENT (OTTI) LOSSES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb8210'), 'mdrm_item': 'RIADJ320', 'description': 'LESS: PORTION OTTI LOSSES IN OTHER COMPREHENSIVE INCOME', 'details': {'start_date': '2010-03-31', 'end_date': '2016-12-31', 'description': 'LESS: PORTION OTTI LOSSES IN OTHER COMPREHENSIVE INCOME', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb8211'), 'mdrm_item': 'RIADJ321', 'description': 'OTTI LOSSES RECOGNIZED IN EARNINGS', 'details': {'start_date': '2010-03-31', 'end_date': '9999-12-31', 'description': 'OTTI LOSSES RECOGNIZED IN EARNINGS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb8212'), 'mdrm_item': 'RIADJ447', 'description': 'GAINS ON BARGAIN PURCHASE', 'details': {'start_date': '2009-12-31', 'end_date': '9999-12-31', 'description': 'GAINS ON BARGAIN PURCHASE', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb8213'), 'mdrm_item': 'RIADJ536', 'description': 'CUMULATIVE EFFECT OF THE INITIAL APPLICATION OF FAS 167 RELATED TO NEWLY CONSOLIDATED VARIABLE INTEREST ENTITIES', 'details': {'start_date': '2010-03-31', 'end_date': '2010-12-31', 'description': 'CUMULATIVE EFFECT OF THE INITIAL APPLICATION OF FAS 167 RELATED TO NEWLY CONSOLIDATED VARIABLE INTEREST ENTITIES', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb8214'), 'mdrm_item': 'RIADJ980', 'description': 'NET CHANGE IN FAIR VALUES OF FINANCIAL INSTRUMENTS ACCOUNTED FOR UNDER A FAIR VALUE OPTION', 'details': {'start_date': '2011-03-31', 'end_date': '9999-12-31', 'description': 'NET CHANGE IN FAIR VALUES OF FINANCIAL INSTRUMENTS ACCOUNTED FOR UNDER A FAIR VALUE OPTION', 'confidential': 'No', 'reporting_forms': 'FR 2886b'}}
# {'_id': ObjectId('5946004ddbc5544250fb8215'), 'mdrm_item': 'RIADK090', 'description': "IMPACT ON TRADING REVENUE OF CHANGES IN THE CREDITWORTHINESS OF THE BANK'S DERIVATIVES COUNTERPARTIES ON THE BANK'S DERIVATIVE ASSETS (INCLUDED IN MEMORANDUM ITEMS 8.A. THROUGH 8.E ABOVE)", 'details': {'start_date': '2011-03-31', 'end_date': '2016-12-31', 'description': "IMPACT ON TRADING REVENUE OF CHANGES IN THE CREDITWORTHINESS OF THE BANK'S DERIVATIVES COUNTERPARTIES ON THE BANK'S DERIVATIVE ASSETS (INCLUDED IN MEMORANDUM ITEMS 8.A. THROUGH 8.E ABOVE)", 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb8216'), 'mdrm_item': 'RIADK094', 'description': "IMPACT ON TRADING REVENUE OF CHANGES IN THE CREDITWORTHINESS OF THE BANK ON THE BANK'S DERIVATIVE LIABILITIES (INCLUDED IN MEMORANDUM ITEMS 8.A. THROUGH 8.E ABOVE)", 'details': {'start_date': '2011-03-31', 'end_date': '2016-12-31', 'description': "IMPACT ON TRADING REVENUE OF CHANGES IN THE CREDITWORTHINESS OF THE BANK ON THE BANK'S DERIVATIVE LIABILITIES (INCLUDED IN MEMORANDUM ITEMS 8.A. THROUGH 8.E ABOVE)", 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb8217'), 'mdrm_item': 'RIADK129', 'description': 'CHARGE-OFFS ON AUTOMOBILE LOANS', 'details': {'start_date': '2011-03-31', 'end_date': '9999-12-31', 'description': 'CHARGE-OFFS ON AUTOMOBILE LOANS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb8218'), 'mdrm_item': 'RIADK133', 'description': 'RECOVERIES ON AUTOMOBILE LOANS', 'details': {'start_date': '2011-03-31', 'end_date': '9999-12-31', 'description': 'RECOVERIES ON AUTOMOBILE LOANS', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb8219'), 'mdrm_item': 'RIADK205', 'description': 'CHARGE-OFFS ALL OTHER (INCLUDES SINGLE PAYMENT, INSTALLMENT, ALL STUDENT LOANS, AND REVOLVING CREDIT PLANS OTHER THAN CREDIT CARDS)', 'details': {'start_date': '2011-03-31', 'end_date': '9999-12-31', 'description': 'CHARGE-OFFS ALL OTHER (INCLUDES SINGLE PAYMENT, INSTALLMENT, ALL STUDENT LOANS, AND REVOLVING CREDIT PLANS OTHER THAN CREDIT CARDS)', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb821a'), 'mdrm_item': 'RIADK206', 'description': 'RECOVERIES ALL OTHER (INCLUDES SINGLE PAYMENT, INSTALLMENT, ALL STUDENT LOANS, AND REVOLVING CREDIT PLANS OTHER THAN CREDIT CARDS)', 'details': {'start_date': '2011-03-31', 'end_date': '9999-12-31', 'description': 'RECOVERIES ALL OTHER (INCLUDES SINGLE PAYMENT, INSTALLMENT, ALL STUDENT LOANS, AND REVOLVING CREDIT PLANS OTHER THAN CREDIT CARDS)', 'confidential': 'No', 'reporting_forms': 'Multiple Forms'}}
# {'_id': ObjectId('5946004ddbc5544250fb821b'), 'mdrm_item': 'RIADT047', 'description': 'INCOME AND FEES FROM WIRE TRANSFERS', 'details': {'start_date': '2016-09-30', 'end_date': '9999-12-31', 'description': 'INCOME AND FEES FROM WIRE TRANSFERS', 'confidential': 'No', 'reporting_forms': nan}}
# {'_id': ObjectId('5946004ddbc5544250fb821c'), 'mdrm_item': 'RIADY923', 'description': 'OTHER REAL ESTATE OWNED EXPENSES', 'details': {'start_date': '2016-09-30', 'end_date': '9999-12-31', 'description': 'OTHER REAL ESTATE OWNED EXPENSES', 'confidential': 'No', 'reporting_forms': nan}}
# {'_id': ObjectId('5946004ddbc5544250fb821d'), 'mdrm_item': 'RIADY924', 'description': 'INSURANCE EXPENSES (NOT INCLUDED IN EMPLOUEE EXPENSES, PREMISES AND FIXED ASSET EXPENSES, AND OTHER REAL ESTATE OWNED EXPENSES)', 'details': {'start_date': '2016-09-30', 'end_date': '9999-12-31', 'description': 'INSURANCE EXPENSES (NOT INCLUDED IN EMPLOUEE EXPENSES, PREMISES AND FIXED ASSET EXPENSES, AND OTHER REAL ESTATE OWNED EXPENSES)', 'confidential': 'No', 'reporting_forms': nan}}

# %%
company_collection.count()
# Out:
# 5

# %%
for obs in company_collection.find():
    print(obs)
# Out:
# {'_id': ObjectId('59460039dbc5544250fb7edd'), 'record_updated': '2013-03-31', 'financial_institution_name': 'WELLS FARGO BANK, NATIONAL ASSOCIATION', 'fdic_certificate_number': 3511, 'location': {'financial_institution_address': '101 NORTH PHILLIPS AVENUE ', 'financial_institution_city': 'SIOUX FALLS', 'financial_institution_state': 'SD', 'financial_institution_zip_code': 57104}, 'identifiers': {'idrssd': 451965, 'occ_charter_number': 1, 'ots_docket_number': 0, 'primary_aba_routing_number': 121000248, 'financial_institution_filing_type': 31}}
# {'_id': ObjectId('59460039dbc5544250fb7ede'), 'record_updated': '2013-03-31', 'financial_institution_name': 'CITIBANK, N.A.', 'fdic_certificate_number': 7213, 'location': {'financial_institution_address': '701 EAST 60TH STREET NORTH ', 'financial_institution_city': 'SIOUX FALLS', 'financial_institution_state': 'SD', 'financial_institution_zip_code': 57104}, 'identifiers': {'idrssd': 476810, 'occ_charter_number': 1461, 'ots_docket_number': 0, 'primary_aba_routing_number': 21000089, 'financial_institution_filing_type': 31}}
# {'_id': ObjectId('59460039dbc5544250fb7edf'), 'record_updated': '2013-03-31', 'financial_institution_name': 'BANK OF AMERICA, NATIONAL ASSOCIATION', 'fdic_certificate_number': 3510, 'location': {'financial_institution_address': '100 NORTH TRYON STREET, SUITE 170 ', 'financial_institution_city': 'CHARLOTTE', 'financial_institution_state': 'NC', 'financial_institution_zip_code': 28202}, 'identifiers': {'idrssd': 480228, 'occ_charter_number': 13044, 'ots_docket_number': 0, 'primary_aba_routing_number': 53000196, 'financial_institution_filing_type': 31}}
# {'_id': ObjectId('59460039dbc5544250fb7ee0'), 'record_updated': '2013-03-31', 'financial_institution_name': 'JPMORGAN CHASE BANK, NATIONAL ASSOCIATION', 'fdic_certificate_number': 628, 'location': {'financial_institution_address': '1111 POLARIS PARKWAY ', 'financial_institution_city': 'COLUMBUS', 'financial_institution_state': 'OH', 'financial_institution_zip_code': 43240}, 'identifiers': {'idrssd': 852218, 'occ_charter_number': 8, 'ots_docket_number': 0, 'primary_aba_routing_number': 21000021, 'financial_institution_filing_type': 31}}
# {'_id': ObjectId('594602b8dbc5544250fb8222'), 'record_updated': '2013-03-31', 'financial_institution_name': 'USAA FEDERAL SAVINGS BANK', 'fdic_certificate_number': 32188, 'location': {'financial_institution_address': '10750 MCDERMOTT FWY ', 'financial_institution_city': 'SAN ANTONIO', 'financial_institution_state': 'TX', 'financial_institution_zip_code': 78288}, 'identifiers': {'idrssd': 619877, 'occ_charter_number': 707975, 'ots_docket_number': 7975, 'primary_aba_routing_number': 314074269, 'financial_institution_filing_type': 41}}

# %%
fdic_collection.count()
# Out:
# 85

# %%
fdic_collection.find_one()
# Out:
# {'_id': ObjectId('59460038dbc5544250fb7ecd'),
#  'fdic_certificate_number': 3511,
#  'financial_institution_name': 'WELLS FARGO BANK, NATIONAL ASSOCIATION',
#  'financials': {'RCFD0071': 187583000.0,
#   'RCFD0081': 19641000.0,
#   'RCFD0426': 22464000.0,
#   'RCFD1248': 0.0,
#   'RCFD1249': 78000.0,
#   'RCFD1250': 2000.0,
#   'RCFD1251': 220000.0,
#   'RCFD1252': 7000.0,
#   'RCFD1253': 560000.0,
#   'RCFD1254': 1000.0,
#   'RCFD1255': 0.0,
#   'RCFD1256': 20000.0,
#   'RCFD1583': 102000.0,
#   'RCFD1594': 16000.0,
#   'RCFD1597': 0.0,
#   'RCFD1754': 12346000.0,
#   'RCFD1773': 215837000.0,
#   'RCFD2130': 662000.0,
#   'RCFD2145': 7582000.0,
#   'RCFD2150': 3838000.0,
#   'RCFD2160': 54238000.0,
#   'RCFD2170': 1373600000.0,
#   'RCFD2930': 27989000.0,
#   'RCFD2948': 1235756000.0,
#   'RCFD3000': 207000.0,
#   'RCFD3123': 12421000.0,
#   'RCFD3163': 21549000.0,
#   'RCFD3190': 55913000.0,
#   'RCFD3200': 19642000.0,
#   'RCFD3210': 137637000.0,
#   'RCFD3230': 519000.0,
#   'RCFD3300': 1373600000.0,
#   'RCFD3505': 170000.0,
#   'RCFD3506': 0.0,
#   'RCFD3507': 128000.0,
#   'RCFD3529': 0.0,
#   'RCFD3530': 0.0,
#   'RCFD3545': 32465000.0,
#   'RCFD3548': 13662000.0,
#   'RCFD3632': 32028000.0,
#   'RCFD3656': 7000.0,
#   'RCFD3838': 0.0,
#   'RCFD3839': 103010000.0,
#   'RCFD5369': 10277000.0,
#   'RCFD5377': 0.0,
#   'RCFD5378': 0.0,
#   'RCFD5379': 0.0,
#   'RCFD5380': 0.0,
#   'RCFD5381': 0.0,
#   'RCFD5382': 0.0,
#   'RCFD5389': 0.0,
#   'RCFD5390': 0.0,
#   'RCFD5391': 0.0,
#   'RCFD5459': 92000.0,
#   'RCFD5460': 3000.0,
#   'RCFD5461': 41000.0,
#   'RCFD6558': 39000.0,
#   'RCFD6559': 1000.0,
#   'RCFD6560': 35000.0,
#   'RCFD6724': nan,
#   'RCFDA130': 0.0,
#   'RCFDB528': 778519000.0,
#   'RCFDB529': 766098000.0,
#   'RCFDB530': 2080000.0,
#   'RCFDB575': 271000.0,
#   'RCFDB576': 255000.0,
#   'RCFDB577': 0.0,
#   'RCFDB989': 18962000.0,
#   'RCFDB995': 13930000.0,
#   'RCFDC226': 205000.0,
#   'RCFDC240': 266000.0,
#   'RCFDC241': 526000.0,
#   'RCFDC410': 1790000.0,
#   'RCFDC411': 266000.0,
#   'RCFDF166': 0.0,
#   'RCFDF167': 0.0,
#   'RCFDF168': 0.0,
#   'RCFDF169': 33000.0,
#   'RCFDF170': 0.0,
#   'RCFDF171': 29000.0,
#   'RCFDF664': 0.0,
#   'RCFDF665': 0.0,
#   'RCFDF666': 190000.0,
#   'RCFDF667': 0.0,
#   'RCFDF668': 0.0,
#   'RCFDF669': 198000.0,
#   'RCFDG105': 137844000.0,
#   'RCFDK036': 1766000.0,
#   'RCFDK037': 21892000.0,
#   'RCFDK038': 366000.0,
#   'RCFDK039': 743000.0,
#   'RCFDK040': 1505000.0,
#   'RCFDK041': 340000.0,
#   'RCFDK042': 999000.0,
#   'RCFDK043': 20175000.0,
#   'RCFDK044': 0.0,
#   'RCFDK072': 0.0,
#   'RCFDK073': 0.0,
#   'RCFDK074': 0.0,
#   'RCFDK075': 0.0,
#   'RCFDK076': 0.0,
#   'RCFDK077': 0.0,
#   'RCFDK078': 0.0,
#   'RCFDK079': 0.0,
#   'RCFDK080': 0.0,
#   'RCFDK081': 0.0,
#   'RCFDK082': 0.0,
#   'RCFDK083': 0.0,
#   'RCFDK084': 0.0,
#   'RCFDK085': 0.0,
#   'RCFDK086': 0.0,
#   'RCFDK087': 0.0,
#   'RCFDK088': 0.0,
#   'RCFDK089': 0.0,
#   'RCFDK091': 0.0,
#   'RCFDK092': 0.0,
#   'RCFDK093': 0.0,
#   'RCFDK095': 0.0,
#   'RCFDK096': 0.0,
#   'RCFDK097': 0.0,
#   'RCFDK099': 0.0,
#   'RCFDK100': 0.0,
#   'RCFDK101': 0.0,
#   'RCFDK102': 0.0,
#   'RCFDK103': 0.0,
#   'RCFDK104': 0.0,
#   'RCFDK120': 11000.0,
#   'RCFDK121': 0.0,
#   'RCFDK122': 353000.0,
#   'RCFDK123': 0.0,
#   'RCFDK124': 0.0,
#   'RCFDK125': 1000.0,
#   'RCFDK126': 43000.0,
#   'RCFDK127': 30000.0,
#   'RCFDK128': 259000.0,
#   'RCFDK134': 0.0,
#   'RCFDK135': 0.0,
#   'RCFDK136': 0.0,
#   'RCFDK138': 0.0,
#   'RCFDK139': 0.0,
#   'RCFDK140': 0.0,
#   'RCFDK213': 897000.0,
#   'RCFDK214': 49000.0,
#   'RCFDK215': 157000.0,
#   'RCFDK216': 830000.0,
#   'RCFDK217': 967000.0,
#   'RCFDK218': 32000.0,
#   'RCFDK269': 0.0,
#   'RCFDK271': 0.0,
#   'RCFDK272': 0.0,
#   'RCFDK274': 0.0,
#   'RCFDK275': 0.0,
#   'RCFDK276': 0.0,
#   'RCFDK277': 0.0,
#   'RCFDK278': 0.0,
#   'RCFDK279': 0.0,
#   'RCFDK280': 0.0,
#   'RCFDK281': 0.0,
#   'RCFDK282': 0.0,
#   'RCFDK283': 0.0,
#   'RCFDK284': 0.0,
#   'RCFDK285': 0.0,
#   'RCFDK286': 0.0,
#   'RCFDK287': 0.0,
#   'RCFDK288': 0.0,
#   'RCFDL183': 3493000.0,
#   'RCFDL184': 10328000.0,
#   'RCFDL185': 0.0,
#   'RCFDL186': 2678000.0,
#   'RCFDL187': 4307000.0,
#   'RCFDL188': 0.0,
#   'RCFN2200': 94619000.0,
#   'RCFN6631': 633000.0,
#   'RCFN6636': 93986000.0,
#   'RCFNB572': 0.0,
#   'RCFNB573': 78000.0,
#   'RCFNB574': 0.0,
#   'RCFNK291': 0.0,
#   'RCFNK292': 0.0,
#   'RCFNK293': 0.0,
#   'RCFNK294': 0.0,
#   'RCFNK295': 0.0,
#   'RCFNK296': 0.0,
#   'RCON0071': nan,
#   'RCON0081': nan,
#   'RCON0426': nan,
#   'RCON1226': nan,
#   'RCON1227': nan,
#   'RCON1228': nan,
#   'RCON1248': nan,
#   'RCON1249': nan,
#   'RCON1250': nan,
#   'RCON1254': nan,
#   'RCON1255': nan,
#   'RCON1256': nan,
#   'RCON1583': nan,
#   'RCON1594': nan,
#   'RCON1597': nan,
#   'RCON1606': nan,
#   'RCON1607': nan,
#   'RCON1608': nan,
#   'RCON1754': 11988000,
#   'RCON1773': 211344000,
#   'RCON2130': nan,
#   'RCON2145': nan,
#   'RCON2150': nan,
#   'RCON2160': nan,
#   'RCON2170': 1334292000,
#   'RCON2200': 1000959000,
#   'RCON2930': nan,
#   'RCON2948': 1196448000,
#   'RCON3000': nan,
#   'RCON3123': nan,
#   'RCON3163': nan,
#   'RCON3190': 55425000,
#   'RCON3200': nan,
#   'RCON3210': nan,
#   'RCON3230': nan,
#   'RCON3300': nan,
#   'RCON3493': 12000,
#   'RCON3494': 0,
#   'RCON3495': 55000,
#   'RCON3499': 73000,
#   'RCON3500': 13000,
#   'RCON3501': 140000,
#   'RCON3505': nan,
#   'RCON3506': nan,
#   'RCON3507': nan,
#   'RCON3529': nan,
#   'RCON3530': nan,
#   'RCON3545': 31310000.0,
#   'RCON3548': 13165000.0,
#   'RCON3632': nan,
#   'RCON3656': nan,
#   'RCON3838': nan,
#   'RCON3839': nan,
#   'RCON5369': nan,
#   'RCON5380': nan,
#   'RCON5381': nan,
#   'RCON5382': nan,
#   'RCON5398': 548000,
#   'RCON5399': 97000,
#   'RCON5400': 2331000,
#   'RCON6631': 272069000,
#   'RCON6636': 728890000,
#   'RCONB987': 51000,
#   'RCONB989': 17038000,
#   'RCONB993': 9042000,
#   'RCONB995': 13891000,
#   'RCONC229': 6614000,
#   'RCONC230': 409000,
#   'RCONC236': 7858000,
#   'RCONC237': 25570000,
#   'RCONC238': 127000,
#   'RCONC239': 34000,
#   'RCONF172': 5000,
#   'RCONF173': 95000,
#   'RCONF174': 14000,
#   'RCONF175': 165000,
#   'RCONF176': 81000,
#   'RCONF177': 375000,
#   'RCONF178': 219000,
#   'RCONF179': 273000,
#   'RCONF180': 23000,
#   'RCONF181': 41000,
#   'RCONF182': 1079000,
#   'RCONF183': 971000,
#   'RCONF661': 695000,
#   'RCONF662': 2257000,
#   'RCONF663': 4472000,
#   'RCONK105': 1000,
#   'RCONK107': 66000,
#   'RCONK108': 1000,
#   'RCONK110': 216000,
#   'RCONK113': 42000,
#   'RCONK114': 20000,
#   'RCONK115': 4000,
#   'RCONK116': 450000,
#   'RCONK117': 46000,
#   'RCONK118': 27000,
#   'RCONK119': 521000,
#   'RIAD0093': 448000,
#   'RIAD3196': -30000,
#   'RIAD4010': 32850000,
#   'RIAD4012': 5526000,
#   'RIAD4020': 257000,
#   'RIAD4024': 167000.0,
#   'RIAD4059': 501000.0,
#   'RIAD4060': 2431000,
#   'RIAD4065': 659000,
#   'RIAD4069': 290000,
#   'RIAD4070': 1706000,
#   'RIAD4073': 2501000,
#   'RIAD4074': 39298000,
#   'RIAD4079': 28133000,
#   'RIAD4080': 5081000,
#   'RIAD4092': 9704000,
#   'RIAD4093': 37078000,
#   'RIAD4107': 41799000,
#   'RIAD4115': 331000,
#   'RIAD4135': 21602000,
#   'RIAD4150': 223040,
#   'RIAD4172': 115000.0,
#   'RIAD4180': 56000,
#   'RIAD4185': 617000,
#   'RIAD4200': 426000,
#   'RIAD4217': 4346000,
#   'RIAD4230': 2082000,
#   'RIAD4300': 19325000,
#   'RIAD4301': 28241000,
#   'RIAD4302': 8916000,
#   'RIAD4313': 90000,
#   'RIAD4340': 19075000,
#   'RIAD4435': 13106000,
#   'RIAD4436': 4969000,
#   'RIAD4507': 784000,
#   'RIAD4508': 66000,
#   'RIAD4513': 22000,
#   'RIAD4518': 221000,
#   'RIAD5415': 268000,
#   'RIAD5416': 1339000,
#   'RIAD8431': 346000.0,
#   'RIAD8757': 1260000.0,
#   'RIAD8758': 712000.0,
#   'RIAD8759': 302000.0,
#   'RIAD8760': 150000.0,
#   'RIADA220': 2392000,
#   'RIADA251': 161000.0,
#   'RIADA517': 339000,
#   'RIADA518': 434000,
#   'RIADB485': 2514000,
#   'RIADB486': 4900000,
#   'RIADB487': 1167000.0,
#   'RIADB488': 11000,
#   'RIADB489': 4749000,
#   'RIADB491': 6000,
#   'RIADB492': 1976000,
#   'RIADB493': 112000,
#   'RIADB496': -8000,
#   'RIADB497': 14377000,
#   'RIADC232': 1426000,
#   'RIADC386': 19000,
#   'RIADC387': 3000,
#   'RIADC886': 360000,
#   'RIADC888': 502000,
#   'RIADC889': -2000,
#   'RIADC890': -6000,
#   'RIADF186': -32000.0,
#   'RIADF228': 42000.0,
#   'RIADF551': 4651000.0,
#   'RIADF552': 141000.0,
#   'RIADG103': 250000,
#   'RIADG104': 19325000,
#   'RIADJ319': -14000,
#   'RIADJ320': -119000,
#   'RIADJ321': 105000,
#   'RIADK090': 187000.0,
#   'RIADK094': -1000.0},
#  'last_datetime_submission_updated_on': '2016-11-30T15:46:50',
#  'reporting_period_end_date': '2013-12-31'}

# %% [markdown]
# #### Review Distinct Fields

# %% [markdown]
# Notice that $5 * 17 = 85$ so that the count of distinct dates, the count of companies, and the count of financial report observations align.

# %%
distinct_dates = fdic_collection.distinct('reporting_period_end_date')

# %%
len(distinct_dates)
# Out:
# 17

# %%
distinct_ids = fdic_collection.distinct('fdic_certificate_number')

# %%
distinct_ids
# Out:
# [3511, 7213, 3510, 628, 32188]

# %%
distinct_names = fdic_collection.distinct('financial_institution_name')

# %%
distinct_names
# Out:
# ['WELLS FARGO BANK, NATIONAL ASSOCIATION',
#  'CITIBANK, N.A.',
#  'BANK OF AMERICA, NATIONAL ASSOCIATION',
#  'JPMORGAN CHASE BANK, NATIONAL ASSOCIATION',
#  'USAA FEDERAL SAVINGS BANK']
